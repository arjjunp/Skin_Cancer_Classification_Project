# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Convolution2D

# %%
from tensorflow.keras.layers import MaxPooling2D

# %%
from tensorflow.keras.layers import Flatten

# %%
from tensorflow.keras.layers import Dense

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
Classifier=Sequential()

# %%
Classifier.add(Convolution2D(32,3,3,input_shape=(220,220,3),activation='relu'))
Classifier.add(MaxPooling2D(pool_size=(2,2)))
Classifier.add(Convolution2D(128,3,3,activation='relu'))
Classifier.add(MaxPooling2D(pool_size=(2,2)))
Classifier.add(Flatten())
Classifier.add(Dense(256, activation='relu'))
Classifier.add(Dense(3, activation='softmax'))

Classifier.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])
Classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 73, 73, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 12, 12, 128)       36992
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               1179904
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 1,218,563
# Trainable params: 1,218,563
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen=ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True)

# %%
test_datagen=ImageDataGenerator(rescale=1./255)

# %%
training_set=train_datagen.flow_from_directory('data1/Train',target_size=(220,220),batch_size=32,class_mode='categorical')
# Out:
# Found 340 images belonging to 3 classes.

# %%
test_set=test_datagen.flow_from_directory('data1/Test',target_size=(220,220),batch_size=32,class_mode='categorical')
# Out:
# Found 86 images belonging to 3 classes.

# %%
from IPython.display import display

# %%
img_dims = 150
epochs = 100
batch_size = 32

# %%
history = Classifier.fit_generator( training_set, steps_per_epoch=training_set.samples // batch_size, 
           epochs=epochs, 
           validation_data=test_set,validation_steps=test_set.samples // batch_size)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 12s 1s/step - loss: 1.2858 - accuracy: 0.3994 - val_loss: 1.0483 - val_accuracy: 0.3594
# Epoch 2/100
# 10/10 [==============================] - 10s 970ms/step - loss: 0.9919 - accuracy: 0.5617 - val_loss: 0.8796 - val_accuracy: 0.5156
# Epoch 3/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.7337 - accuracy: 0.6916 - val_loss: 0.6231 - val_accuracy: 0.7656
# Epoch 4/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.5773 - accuracy: 0.7922 - val_loss: 0.5667 - val_accuracy: 0.7500
# Epoch 5/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.5604 - accuracy: 0.7565 - val_loss: 0.3398 - val_accuracy: 0.9062
# Epoch 6/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.5133 - accuracy: 0.8019 - val_loss: 0.3307 - val_accuracy: 0.8750
# Epoch 7/100
# 10/10 [==============================] - 10s 990ms/step - loss: 0.3566 - accuracy: 0.8571 - val_loss: 0.3284 - val_accuracy: 0.8594
# Epoch 8/100
# 10/10 [==============================] - 10s 984ms/step - loss: 0.4231 - accuracy: 0.8117 - val_loss: 0.4213 - val_accuracy: 0.9219
# Epoch 9/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.3875 - accuracy: 0.8636 - val_loss: 0.3281 - val_accuracy: 0.8594
# Epoch 10/100
# 10/10 [==============================] - 10s 981ms/step - loss: 0.4973 - accuracy: 0.8344 - val_loss: 0.3067 - val_accuracy: 0.8906
# Epoch 11/100
# 10/10 [==============================] - 10s 983ms/step - loss: 0.3445 - accuracy: 0.8571 - val_loss: 0.2815 - val_accuracy: 0.8750
# Epoch 12/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.3231 - accuracy: 0.8766 - val_loss: 0.4491 - val_accuracy: 0.8594
# Epoch 13/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.2955 - accuracy: 0.8766 - val_loss: 0.3866 - val_accuracy: 0.7812
# Epoch 14/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.2967 - accuracy: 0.8734 - val_loss: 0.2531 - val_accuracy: 0.9531
# Epoch 15/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.2623 - accuracy: 0.9026 - val_loss: 0.2995 - val_accuracy: 0.9062
# Epoch 16/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.2957 - accuracy: 0.8734 - val_loss: 0.2554 - val_accuracy: 0.9062
# Epoch 17/100
# 10/10 [==============================] - 11s 1s/step - loss: 0
100
# 10/10 [==============================] - 10s 1s/step - loss: 0.1170 - accuracy: 0.9675 - val_loss: 0.3596 - val_accuracy: 0.9062
# Epoch 66/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.1347 - accuracy: 0.9344 - val_loss: 0.3020 - val_accuracy: 0.9219
# Epoch 67/100
# 10/10 [==============================] - 10s 981ms/step - loss: 0.0515 - accuracy: 0.9773 - val_loss: 0.4313 - val_accuracy: 0.9062
# Epoch 68/100
# 10/10 [==============================] - 10s 973ms/step - loss: 0.1585 - accuracy: 0.9416 - val_loss: 0.2725 - val_accuracy: 0.8906
# Epoch 69/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.1437 - accuracy: 0.9563 - val_loss: 0.3238 - val_accuracy: 0.9062
# Epoch 70/100
# 10/10 [==============================] - 10s 974ms/step - loss: 0.0354 - accuracy: 0.9935 - val_loss: 0.2888 - val_accuracy: 0.8750
# Epoch 71/100
# 10/10 [==============================] - 10s 994ms/step - loss: 0.1267 - accuracy: 0.9610 - val_loss: 0.4364 - val_accuracy: 0.9062
# Epoch 72/100
# 10/10 [==============================] - 10s 977ms/step - loss: 0.0953 - accuracy: 0.9643 - val_loss: 2.2985 - val_accuracy: 0.7500
# Epoch 73/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.1424 - accuracy: 0.9740 - val_loss: 0.3273 - val_accuracy: 0.8906
# Epoch 74/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.0552 - accuracy: 0.9838 - val_loss: 0.2744 - val_accuracy: 0.9062
# Epoch 75/100
# 10/10 [==============================] - 10s 980ms/step - loss: 0.0691 - accuracy: 0.9773 - val_loss: 0.7899 - val_accuracy: 0.8594
# Epoch 76/100
# 10/10 [==============================] - 10s 972ms/step - loss: 0.1093 - accuracy: 0.9643 - val_loss: 0.3786 - val_accuracy: 0.9062
# Epoch 77/100
# 10/10 [==============================] - 10s 973ms/step - loss: 0.0322 - accuracy: 0.9903 - val_loss: 0.5006 - val_accuracy: 0.9062
# Epoch 78/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.1943 - accuracy: 0.9318 - val_loss: 0.3465 - val_accuracy: 0.8750
# Epoch 79/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.0514 - accuracy: 0.9773 - val_loss: 0.3991 - val_accuracy: 0.8906
# Epoch 80/100
# 10/10 [==============================] - 10s 965ms/step - loss: 0.0318 - accuracy: 0.9903 - val_loss: 0.4641 - val_accuracy: 0.8750
# Epoch 81/100
# 10/10 [==============================] - 10s 984ms/step - loss: 0.1551 - accuracy: 0.9643 - val_loss: 0.2444 - val_accuracy: 0.9375
# Epoch 82/100
# 10/10 [==============================] - 10s 998ms/step - loss: 0.0745 - accuracy: 0.9773 - val_loss: 0.4270 - val_accuracy: 0.8906
# Epoch 83/100
# 10/10 [==============================] - 10s 988ms/step - loss: 0.1724 - accuracy: 0.9513 - val_loss: 0.5419 - val_accuracy: 0.8906
# Epoch 84/100
# 10/10 [==============================] - 10s 995ms/step - loss: 0.1380 - accuracy: 0.9610 - val_loss: 0.3650 - val_accuracy: 0.9062
# Epoch 85/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.0682 - accuracy: 0.9740 - val_loss: 0.3263 - val_accuracy: 0.8906
# Epoch 86/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.1120 - accuracy: 0.9578 - val_loss: 0.2297 - val_accuracy: 0.9219
# Epoch 87/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.0625 - accuracy: 0.9773 - val_loss: 0.5243 - val_accuracy: 0.8906
# Epoch 88/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.0348 - accuracy: 0.9903 - val_loss: 0.5464 - val_accuracy: 0.8906
# Epoch 89/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.0588 - accuracy: 0.9838 - val_loss: 0.7416 - val_accuracy: 0.7656
# Epoch 90/100
# 10/10 [==============================] - 10s 989ms/step - loss: 0.1047 - accuracy: 0.9643 - val_loss: 0.3131 - val_accuracy: 0.9219
# Epoch 91/100
# 10/10 [==============================] - 10s 975ms/step - loss: 0.0534 - accuracy: 0.9870 - val_loss: 0.4711 - val_accuracy: 0.9062
# Epoch 92/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.2840 - accuracy: 0.9286 - val_loss: 0.4454 - val_accuracy: 0.8906
# Epoch 93/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.1074 - accuracy: 0.9513 - val_loss: 0.3134 - val_accuracy: 0.9062
# Epoch 94/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.0621 - accuracy: 0.9805 - val_loss: 0.6811 - val_accuracy: 0.8906
# Epoch 95/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.0652 - accuracy: 0.9708 - val_loss: 0.5506 - val_accuracy: 0.8750
# Epoch 96/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.0076 - accuracy: 0.9969 - val_loss: 0.4385 - val_accuracy: 0.8594
# Epoch 97/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.1585 - accuracy: 0.9675 - val_loss: 0.5172 - val_accuracy: 0.8594
# Epoch 98/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.5546 - val_accuracy: 0.9062
# Epoch 99/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.2129 - accuracy: 0.9448 - val_loss: 0.2153 - val_accuracy: 0.9219
# Epoch 100/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.0953 - accuracy: 0.9773 - val_loss: 0.6728 - val_accuracy: 0.8750

# %%
import h5py

# %%
Classifier.save('skin_cancer1.h5')

# %%
from keras.models import load_model

# %%
model=load_model('skin_cancer1.h5')

# %%
import numpy as np

# %%
from tensorflow.keras.preprocessing import image
test_image=image.load_img('m1.jpg',target_size=(220,220))

# %%
import matplotlib.pyplot as plt
img = plt.imshow(test_image)

# %%
test_image=image.load_img('m1.jpg',target_size=(220,220))

# %%
test_image=np.expand_dims(test_image,axis=0)

# %%
result=Classifier.predict(test_image)

# %%
prediction = result[0]

# %%
classes=training_set.class_indices

# %%
classes
# Out:
# {'malignant': 0, 'squamous cell carcinoma': 1, 'vascular lesion': 2}

# %%
prediction=list(prediction)

# %%
prediction
# Out:
# [1.0, 0.0, 0.0]

# %%
classes=['malignant','squamous cell carcinoma','vascular lesion']

# %%
output=zip(classes,prediction)
output=dict(output)

# %%
output
# Out:
# {'malignant': 1.0, 'squamous cell carcinoma': 0.0, 'vascular lesion': 0.0}

# %%
if output["malignant"] == 1.0:
    print("malignant")
elif output["squamous cell carcinoma"] ==1.0:
    print("squamous cell carcinoma")
else:
    print("vascular lesion")
# Out:
# malignant

# %%
def graph():
    #Plot training & validation accuracy values
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()

    # Plot training & validation loss values
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()
graph()
